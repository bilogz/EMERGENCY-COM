# %%
import json
from typing import Dict, Set

import pandas as pd
import yaml
from IPython.display import display

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

psg_directory = "../resources/"
psg_data_file = "psgc_2025-10-13.csv"

# %%
df = pd.read_csv(psg_directory + psg_data_file)
display(df.info())
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43769 entries, 0 to 43768
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   psgc_id                43769 non-null  int64
#  1   name                   43769 non-null  object
#  2   correspondence_code    43719 non-null  float64
#  3   geographic_level       43767 non-null  object
#  4   old_names              1699 non-null   object
#  5   city_class             149 non-null    object
#  6   income_classification  1724 non-null   object
#  7   settlement_type        42011 non-null  object
#  8    population            43768 non-null  object
#  9   Unnamed: 9             18 non-null     object
#  10  barangay_status        2855 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 3.7+ MB
# None
#           psgc_id                           name  correspondence_code  \
# 0      1300000000  National Capital Region (NCR)          130000000.0
# 1      1380100000               City of Caloocan          137501000.0
# 2      1380100001                     Barangay 1          137501001.0
# 3      1380100002                     Barangay 2          137501002.0
# 4      1380100003                     Barangay 3          137501003.0
# ...           ...                            ...                  ...
# 43764  1999908006                     Manaulanan          124712037.0
# 43765  1999908007                       Pamalian          124712062.0
# 43766  1999908008                        Tapodoc          124717017.0
# 43767  1999908009                       Macabual          124712034.0
# 43768  1999908010                      Panicupan          124712048.0
#
#       geographic_level old_names city_class income_classification  \
# 0                  Reg       NaN        NaN                   NaN
# 1                 City       NaN        HUC                   1st
# 2                  Bgy       NaN        NaN                   NaN
# 3                  Bgy       NaN        NaN                   NaN
# 4                  Bgy       NaN        NaN                   NaN
# ...                ...       ...        ...                   ...
# 43764              Bgy       NaN        NaN                   NaN
# 43765              Bgy       NaN        NaN                   NaN
# 43766              Bgy       NaN        NaN                   NaN
# 43767              Bgy       NaN        NaN                   NaN
# 43768              Bgy       NaN        NaN                   NaN
#
#       settlement_type     population Unnamed: 9 barangay_status
# 0                 NaN    14,001,751         NaN             NaN
# 1                 NaN     1,712,945         NaN             NaN
# 2                   U         2,356         NaN             NaN
# 3                   U         5,226         NaN             NaN
# 4                   U         2,544         NaN             NaN
# ...               ...            ...        ...             ...
# 43764               U         7,790         NaN             NaN
# 43765               R         2,981         NaN             NaN
# 43766               R         1,797         NaN             NaN
# 43767               R         4,311         NaN             NaN
# 43768               R         2,173         NaN             NaN
#
# [43769 rows x 11 columns]

# %%
df["psgc_id"] = df["psgc_id"].astype(str).str.zfill(10)
df = df.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
geographic_level_map = {
    "Reg":"region",
    "City":"city",
    "Mun":"municipality",
    "Prov":"province",
    "SubMun":"submunicipality", 
    "Bgy":"barangay"
}
df["geographic_level"] = df["geographic_level"].replace(geographic_level_map)

df["barangay_code"] = df["psgc_id"].str[-3:]
df["municipal_or_city_code"] = df["psgc_id"].str[-5:-3]
df["province_or_huc_code"] = df["psgc_id"].str[-8:-5]
df["region_code"] = df["psgc_id"].str[-10:-8]

df["barangay_mapper"] = df["psgc_id"].str[-10:]
df["municipal_or_city_mapper"] = df["psgc_id"].str[-10:-3]
df["province_or_huc_mapper"] = df["psgc_id"].str[-10:-5]
df["region_mapper"] = df["psgc_id"].str[-10:-8]

df.sample(10)
# Out:
#           psgc_id          name  correspondence_code geographic_level  \
# 5446   0105517025      Talibaew           15517025.0         barangay
# 2867   1408107002      Consuelo          148107002.0         barangay
# 37796  1102315006   Consolacion          112315006.0         barangay
# 17179  1705308011        Talaga          175308011.0         barangay
# 18686  0501608006      Capacuan           51608006.0         barangay
# 4738   0103311024     Lioac Sur           13311024.0         barangay
# 136    1380100135  Barangay 135          137501135.0         barangay
# 16563  1705110013       Batasan          175110013.0         barangay
# 2812   1408104016       Magabta          148104016.0         barangay
# 21003  0506208000         Gubat           56208000.0     municipality
#
#       old_names city_class income_classification settlement_type  population  \
# 5446        NaN        NaN                   NaN               R       4,757
# 2867        NaN        NaN                   NaN               R         974
# 37796       NaN        NaN                   NaN               R       1,839
# 17179       NaN        NaN                   NaN               R       1,145
# 18686       NaN        NaN                   NaN               R       2,346
# 4738        NaN        NaN                   NaN               R       1,309
# 136         NaN        NaN                   NaN               U         634
# 16563       NaN        NaN                   NaN               R       3,440
# 2812        NaN        NaN                   NaN               R         187
# 21003       NaN        NaN                   1st             NaN      61,095
#
#       Unnamed: 9 barangay_status barangay_code municipal_or_city_code  \
# 5446         NaN             NaN           025                     17
# 2867         NaN             NaN           002                     07
# 37796        NaN             NaN           006                     15
# 17179        NaN             NaN           011                     08
# 18686        NaN             NaN           006                     08
# 4738         NaN             NaN           024                     11
# 136          NaN             NaN           135                     00
# 16563        NaN             NaN           013                     10
# 2812         NaN             NaN           016                     04
# 21003        NaN             NaN           000                     08
#
#       province_or_huc_code region_code barangay_mapper  \
# 5446                   055          01      0105517025
# 2867                   081          14      1408107002
# 37796                  023          11      1102315006
# 17179                  053          17      1705308011
# 18686                  016          05      0501608006
# 4738                   033          01      0103311024
# 136                    801          13      1380100135
# 16563                  051          17      1705110013
# 2812                   081          14      1408104016
# 21003                  062          05      0506208000
#
#       municipal_or_city_mapper province_or_huc_mapper region_mapper
# 5446                   0105517                  01055            01
# 2867                   1408107                  14081            14
# 37796                  1102315                  11023            11
# 17179                  1705308                  17053            17
# 18686                  0501608                  05016            05
# 4738                   0103311                  01033            01
# 136                    1380100                  13801            13
# 16563                  1705110                  17051            17
# 2812                   1408104                  14081            14
# 21003                  0506208                  05062            05

# %%
regions_filter = (
    (df["province_or_huc_code"] == "000")
    & (df["municipal_or_city_code"] == "00")
    & (df["barangay_code"] == "000")
)
regions_mapper = (
    df.loc[regions_filter, ["region_mapper", "name"]]
    .sort_values("region_mapper")
    .set_index("region_mapper", drop=True)
    .to_dict()["name"]
)
regions_mapper
# Out:
# {'01': 'Region I (Ilocos Region)',
#  '02': 'Region II (Cagayan Valley)',
#  '03': 'Region III (Central Luzon)',
#  '04': 'Region IV-A (CALABARZON)',
#  '05': 'Region V (Bicol Region)',
#  '06': 'Region VI (Western Visayas)',
#  '07': 'Region VII (Central Visayas)',
#  '08': 'Region VIII (Eastern Visayas)',
#  '09': 'Region IX (Zamboanga Peninsula)',
#  '10': 'Region X (Northern Mindanao)',
#  '11': 'Region XI (Davao Region)',
#  '12': 'Region XII (SOCCSKSARGEN)',
#  '13': 'National Capital Region (NCR)',
#  '14': 'Cordillera Administrative Region (CAR)',
#  '16': 'Region XIII (Caraga)',
#  '17': 'MIMAROPA Region',
#  '18': 'Negros Island Region (NIR)',
#  '19': 'Bangsamoro Autonomous Region In Muslim Mindanao (BARMM)'}

# %%
province_or_huc_filter = (
    ~(df["province_or_huc_code"] == "000")
    & (df["municipal_or_city_code"] == "00")
    & (df["barangay_code"] == "000")
)

province_or_huc_mapper = (
    df.loc[province_or_huc_filter, ["province_or_huc_mapper", "name"]]
    .sort_values("province_or_huc_mapper")
    .set_index("province_or_huc_mapper")
    .to_dict()["name"]
)
province_or_huc_mapper
# Out:
# {'01028': 'Ilocos Norte',
#  '01029': 'Ilocos Sur',
#  '01033': 'La Union',
#  '01055': 'Pangasinan',
#  '02009': 'Batanes',
#  '02015': 'Cagayan',
#  '02031': 'Isabela',
#  '02050': 'Nueva Vizcaya',
#  '02057': 'Quirino',
#  '03008': 'Bataan',
#  '03014': 'Bulacan',
#  '03049': 'Nueva Ecija',
#  '03054': 'Pampanga',
#  '03069': 'Tarlac',
#  '03071': 'Zambales',
#  '03077': 'Aurora',
#  '03301': 'City of Angeles',
#  '03314': 'City of Olongapo',
#  '04010': 'Batangas',
#  '04021': 'Cavite',
#  '04034': 'Laguna',
#  '04056': 'Quezon',
#  '04058': 'Rizal',
#  '04312': 'City of Lucena',
#  '05005': 'Albay',
#  '05016': 'Camarines Norte',
#  '05017': 'Camarines Sur',
#  '05020': 'Catanduanes',
#  '05041': 'Masbate',
#  '05062': 'Sorsogon',
#  '06004': 'Aklan',
#  '06006': 'Antique',
#  '06019': 'Capiz',
#  '06030': 'Iloilo',
#  '06079': 'Guimaras',
#  '06310': 'City of Iloilo',
#  '07012': 'Bohol',
#  '07022': 'Cebu',
#  '07306': 'City of Cebu',
#  '07311': 'City of Lapu-Lapu',
#  '07313': 'City of Mandaue',
#  '08026': 'Eastern Samar',
#  '08037': 'Leyte',
#  '08048': 'Northern Samar',
#  '08060': 'Samar',
#  '08064': 'Southern Leyte',
#  '08078': 'Biliran',
#  '08316': 'City of Tacloban',
#  '09066': 'Sulu',
#  '09072': 'Zamboanga del Norte',
#  '09073': 'Zamboanga del Sur',
#  '09083': 'Zamboanga Sibugay',
#  '09317': 'City of Zamboanga',
#  '09901': 'City of Isabela (Not a Province)',
#  '10013': 'Bukidnon',
#  '10018': 'Camiguin',
#  '10035': 'Lanao del Norte',
#  '10042': 'Misamis Occidental',
#  '10043': 'Misamis Oriental',
#  '10305': 'City of Cagayan De Oro',
#  '10309': 'City of Iligan',
#  '11023': 'Davao del Norte',
#  '11024': 'Davao del Sur',
#  '11025': 'Davao Oriental',
#  '11082': 'Davao de Oro',
#  '11086': 'Davao Occidental',
#  '11307': 'City of Davao',
#  '12047': 'Cotabato',
#  '12063': 'South Cotabato',
#  '12065': 'Sultan Kudarat',
#  '12080': 'Sarangani',
#  '12308': 'City of General Santos',
#  '13801': 'City of Caloocan',
#  '13802': 'City of Las Piñas',
#  '13803': 'City of Makati',
#  '13804': 'City of Malabon',
#  '13805': 'City of Mandaluyong',
#  '13806': 'City of Manila',
#  '13807': 'City of Marikina',
#  '13808': 'City of Muntinlupa',
#  '13809': 'City of Navotas',
#  '13810': 'City of Parañaque',
#  '13811': 'Pasay City',
#  '13812': 'City of Pasig',
#  '13813': 'Quezon City',
#  '13814': 'City of San Juan',
#  '13815': 'City of Taguig',
#  '13816': 'City of Valenzuela',
#  '14001': 'Abra',
#  '14011': 'Benguet',
#  '14027': 'Ifugao',
#  '14032': 'Kalinga',
#  '14044': 'Mountain Province',
#  '14081': 'Apayao',
#  '14303': 'City of Baguio',
#  '16002': 'Agusan del Norte',
#  '16003': 'Agusan del Sur',
#  '16067': 'Surigao del Norte',
#  '16068': 'Surigao del Sur',
#  '16085': 'Dinagat Islands',
#  '16304': 'City of Butuan',
#  '17040': 'Marinduque',
#  '17051': 'Occidental Mindoro',
#  '17052': 'Oriental Mindoro',
#  '17053': 'Palawan',
#  '17059': 'Romblon',
#  '17315': 'City of Puerto Princesa',
#  '18045': 'Negros Occidental',
#  '18046': 'Negros Oriental',
#  '18061': 'Siquijor',
#  '18302': 'City of Bacolod',
#  '19007': 'Basilan',
#  '19036': 'Lanao del Sur',
#  '19070': 'Tawi-Tawi',
#  '19087': 'Maguindanao del Norte',
#  '19088': 'Maguindanao del Sur',
#  '19999': 'Special Geographic Area'}

# %%
municipal_or_city_filter = (
    ~(df["province_or_huc_code"] == "000")
    & ~(df["municipal_or_city_code"] == "00")
    & (df["barangay_code"] == "000")
)

municipal_or_city_mapper = (
    df.loc[municipal_or_city_filter, ["municipal_or_city_mapper", "name"]]
    .sort_values("municipal_or_city_mapper")
    .set_index("municipal_or_city_mapper")
    .to_dict()["name"]
)
municipal_or_city_mapper
# Out:
# {'0102801': 'Adams',
#  '0102802': 'Bacarra',
#  '0102803': 'Badoc',
#  '0102804': 'Bangui',
#  '0102805': 'City of Batac',
#  '0102806': 'Burgos',
#  '0102807': 'Carasi',
#  '0102808': 'Currimao',
#  '0102809': 'Dingras',
#  '0102810': 'Dumalneg',
#  '0102811': 'Banna',
#  '0102812': 'City of Laoag',
#  '0102813': 'Marcos',
#  '0102814': 'Nueva Era',
#  '0102815': 'Pagudpud',
#  '0102816': 'Paoay',
#  '0102817': 'Pasuquin',
#  '0102818': 'Piddig',
#  '0102819': 'Pinili',
#  '0102820': 'San Nicolas',
#  '0102821': 'Sarrat',
#  '0102822': 'Solsona',
#  '0102823': 'Vintar',
#  '0102901': 'Alilem',
#  '0102902': 'Banayoyo',
#  '0102903': 'Bantay',
#  '0102904': 'Burgos',
#  '0102905': 'Cabugao',
#  '0102906': 'City of Candon',
#  '0102907': 'Caoayan',
#  '0102908': 'Cervantes',
#  '0102909': 'Galimuyod',
#  '0102910': 'Gregorio del Pilar',
#  '0102911': 'Lidlidda',
#  '0102912': 'Magsingal',
#  '0102913': 'Nagbukel',
#  '0102914': 'Narvacan',
#  '0102915': 'Quirino',
#  '0102916': 'Salcedo',
#  '0102917': 'San Emilio',
#  '0102918': 'San Esteban',
#  '0102919': 'San Ildefonso',
#  '0102920': 'San Juan',
#  '0102921': 'San Vicente',
#  '0102922': 'Santa',
#  '0102923': 'Santa Catalina',
#  '0102924': 'Santa Cruz',
#  '0102925': 'Santa Lucia',
#  '0102926': 'Santa Maria',
#  '0102927': 'Santiago',
#  '0102928': 'Santo Domingo',
#  '0102929': 'Sigay',
#  '0102930': 'Sinait',
#  '0102931': 'Sugpon',
#  '0102932': 'Suyo',
#  '0102933': 'Tagudin',
#  '0102934': 'City of Vigan',
#  '0103301': 'Agoo',
#  '0103302': 'Aringay',
#  '0103303': 'Bacnotan',
#  '0103304': 'Bagulin',
#  '0103305': 'Balaoan',
#  '0103306': 'Bangar',
#  '0103307': 'Bauang',
#  '0103308': 'Burgos',
#  '0103309': 'Caba',
#  '0103310': 'Luna',
#  '0103311': 'Naguilian',
#  '0103312': 'Pugo',
#  '0103313': 'Rosario',
#  '0103314': 'City of San Fernando',
#  '0103315': 'San Gabriel',
#  '0103316': 'San Juan',
#  '0103317': 'Santo Tomas',
#  '0103318': 'Santol',
#  '0103319': 'Sudipen',
#  '0103320': 'Tubao',
#  '0105501': 'Agno',
#  '0105502': 'Aguilar',
#  '0105503': 'City of Alaminos',
#  '0105504': 'Alcala',
#  '0105505': 'Anda',
#  '0105506': 'Asingan',
#  '0105507': 'Balungao',
#  '0105508': 'Bani',
#  '0105509': 'Basista',
#  '0105510': 'Bautista',
#  '0105511': 'Bayambang',
#  '0105512': 'Binalonan',
#  '0105513': 'Binmaley',
#  '0105514': 'Bolinao',
#  '0105515': 'Bugallon',
#  '0105516': 'Burgos',
#  '0105517': 'Calasiao',
#  '0105518': 'City of Dagupan',
#  '0105519': 'Dasol',
#  '0105520': 'Infanta',
#  '0105521': 'Labrador',
#  '0105522': 'Lingayen',
#  '0105523': 'Mabini',
#  '0105524': 'Malasiqui',
#  '0105525': 'Manaoag',
#  '0105526': 'Mangaldan',
#  '0105527': 'Mangatarem',
#  '0105528': 'Mapandan',
#  '0105529': 'Natividad',
#  '0105530': 'Pozorrubio',
#  '0105531': 'Rosales',
#  '0105532': 'City of San Carlos',
#  '0105533': 'San Fabian',
#  '0105534': 'San Jacinto',
#  '0105535': 'San Manuel',
#  '0105536': 'San Nicolas',
#  '0105537': 'San Quintin',
#  '0105538': 'Santa Barbara',
#  '0105539': 'Santa Maria',
#  '0105540': 'Santo Tomas',
#  '0105541': 'Sison',
#  '0105542': 'Sual',
#  '0105543': 'Tayug',
#  '0105544': 'Umingan',
#  '0105545': 'Urbiztondo',
#  '0105546': 'City of Urdaneta',
#  '0105547': 'Villasis',
#  '0105548': 'Laoac',
#  '0200901': 'Basco',
#  '0200902': 'Itbayat',
#  '0200903': 'Ivana',
#  '0200904': 'Mahatao',
#  '0200905': 'Sabtang',
#  '0200906': 'Uyugan',
#  '0201501': 'Abulug',
#  '0201502': 'Alcala',
#  '0201503': 'Allacapan',
#  '0201504': 'Amulung',
#  '0201505': 'Aparri',
#  '0201506': 'Baggao',
#  '0201507': 'Ballesteros',
#  '0201508': 'Buguey',
#  '0201509': 'Calayan',
#  '0201510': 'Camalaniugan',
#  '0201511': 'Claveria',
#  '0201512': 'Enrile',
#  '0201513': 'Gattaran',
#  '0201514': 'Gonzaga',
#  '0201515': 'Iguig',
#  '0201516': 'Lal-Lo',
#  '0201517': 'Lasam',
#  '0201518': 'Pamplona',
#  '0201519': 'Peñablanca',
#  '0201520': 'Piat',
#  '0201521': 'Rizal',
#  '0201522': 'Sanchez-Mira',
#  '0201523': 'Santa Ana',
#  '0201524': 'Santa Praxedes',
#  '0201525': 'Santa Teresita',
#  '0201526': 'Santo Niño',
#  '0201527': 'Solana',
#  '0201528': 'Tuao',
#  '0201529': 'Tuguegarao City',
#  '0203101': 'Alicia',
#  '0203102': 'Angadanan',
#  '0203103': 'Aurora',
#  '0203104': 'Benito Soliven',
#  '0203105': 'Burgos',
#  '0203106': 'Cabagan',
#  '0203107': 'Cabatuan',
#  '0203108': 'City of Cauayan',
#  '0203109': 'Cordon',
#  '0203110': 'Dinapigue',
#  '0203111': 'Divilacan',
#  '0203112': 'Echague',
#  '0203113': 'Gamu',
#  '0203114': 'City of Ilagan',
#  '0203115': 'Jones',
#  '0203116': 'Luna',
#  '0203117': 'Maconacon',
#  '0203118': 'Delfin Albano',
#  '0203119': 'Mallig',
#  '0203120': 'Naguilian',
#  '0203121': 'Palanan',
#  '0203122': 'Quezon',
#  '0203123': 'Quirino',
#  '0203124': 'Ramon',
#  '0203125': 'Reina Mercedes',
#  '0203126': 'Roxas',
#  '0203127': 'San Agustin',
#  '0203128': 'San Guillermo',
#  '0203129': 'San Isidro',
#  '0203130': 'San Manuel',
#  '0203131': 'San Mariano',
#  '0203132': 'San Mateo',
#  '0203133': 'San Pablo',
#  '0203134': 'Santa Maria',
#  '0203135': 'City of Santiago',
#  '0203136': 'Santo Tomas',
#  '0203137': 'Tumauini',
#  '0205001': 'Ambaguio',
#  '0205002': 'Aritao',
#  '0205003': 'Bagabag',
#  '0205004': 'Bambang',
#  '0205005': 'Bayombong',
#  '0205006': 'Diadi',
#  '0205007': 'Dupax del Norte',
#  '0205008': 'Dupax del Sur',
#  '0205009': 'Kasibu',
#  '0205010': 'Kayapa',
#  '0205011': 'Quezon',
#  '0205012': 'Santa Fe',
#  '0205013': 'Solano',
#  '0205014': 'Villaverde',
#  '0205015': 'Alfonso Castaneda',
#  '0205701': 'Aglipay',
#  '0205702': 'Cabarroguis',
#  '0205703': 'Diffun',
#  '0205704': 'Maddela',
#  '0205705': 'Saguday',
#  '0205706': 'Nagtipunan',
#  '0300801': 'Abucay',
#  '0300802': 'Bagac',
#  '0300803': 'City of Balanga',
#  '0300804': 'Dinalupihan',
#  '0300805': 'Hermosa',
#  '0300806': 'Limay',
#  '0300807': 'Mariveles',
#  '0300808': 'Morong',
#  '0300809': 'Orani',
#  '0300810': 'Orion',
#  '0300811': 'Pilar',
#  '0300812': 'Samal',
#  '0301401': 'Angat',
#  '0301402': 'Balagtas',
#  '0301403': 'City of Baliwag',
#  '0301404': 'Bocaue',
#  '0301405': 'Bulacan',
#  '0301406': 'Bustos',
#  '0301407': 'Calumpit',
#  '0301408': 'Guiguinto',
#  '0301409': 'Hagonoy',
#  '0301410': 'City of Malolos',
#  '0301411': 'Marilao',
#  '0301412': 'City of Meycauayan',
#  '0301413': 'Norzagaray',
#  '0301414': 'Obando',
#  '0301415': 'Pandi',
#  '0301416': 'Paombong',
#  '0301417': 'Plaridel',
#  '0301418': 'Pulilan',
#  '0301419': 'San Ildefonso',
#  '0301420': 'City of San Jose Del Monte',
#  '0301421': 'San Miguel',
#  '0301422': 'San Rafael',
#  '0301423': 'Santa Maria',
#  '0301424': 'Doña Remedios Trinidad',
#  '0304901': 'Aliaga',
#  '0304902': 'Bongabon',
#  '0304903': 'City of Cabanatuan',
#  '0304904': 'Cabiao',
#  '0304905': 'Carranglan',
#  '0304906': 'Cuyapo',
#  '0304907': 'Gabaldon',
#  '0304908': 'City of Gapan',
#  '0304909': 'General Mamerto Natividad',
#  '0304910': 'General Tinio',
#  '0304911': 'Guimba',
#  '0304912': 'Jaen',
#  '0304913': 'Laur',
#  '0304914': 'Licab',
#  '0304915': 'Llanera',
#  '0304916': 'Lupao',
#  '0304917': 'Science City of Muñoz',
#  '0304918': 'Nampicuan',
#  '0304919': 'City of Palayan',
#  '0304920': 'Pantabangan',
#  '0304921': 'Peñaranda',
#  '0304922': 'Quezon',
#  '0304923': 'Rizal',
#  '0304924': 'San Antonio',
#  '0304925': 'San Isidro',
#  '0304926': 'San Jose City',
#  '0304927': 'San Leonardo',
#  '0304928': 'Santa Rosa',
#  '0304929': 'Santo Domingo',
#  '0304930': 'Talavera',
#  '0304931': 'Talugtug',
#  '0304932': 'Zaragoza',
#  '0305402': 'Apalit',
#  '0305403': 'Arayat',
#  '0305404': 'Bacolor',
#  '0305405': 'Candaba',
#  '0305406': 'Floridablanca',
#  '0305407': 'Guagua',
#  '0305408': 'Lubao',
#  '0305409': 'Mabalacat City',
#  '0305410': 'Macabebe',
#  '0305411': 'Magalang',
#  '0305412': 'Masantol',
#  '0305413': 'Mexico',
#  '0305414': 'Minalin',
#  '0305415': 'Porac',
#  '0305416': 'City of San Fernando',
#  '0305417': 'San Luis',
#  '0305418': 'San Simon',
#  '0305419': 'Santa Ana',
#  '0305420': 'Santa Rita',
#  '0305421': 'Sto. Tomas',
#  '0305422': 'Sasmuan',
#  '0306901': 'Anao',
#  '0306902': 'Bamban',
#  '0306903': 'Camiling',
#  '0306904': 'Capas',
#  '0306905': 'Concepcion',
#  '0306906': 'Gerona',
#  '0306907': 'La Paz',
#  '0306908': 'Mayantoc',
#  '0306909': 'Moncada',
#  '0306910': 'Paniqui',
#  '0306911': 'Pura',
#  '0306912': 'Ramos',
#  '0306913': 'San Clemente',
#  '0306914': 'San Manuel',
#  '0306915': 'Santa Ignacia',
#  '0306916': 'City of Tarlac',
#  '0306917': 'Victoria',
#  '0306918': 'San Jose',
#  '0307101': 'Botolan',
#  '0307102': 'Cabangan',
#  '0307103': 'Candelaria',
#  '0307104': 'Castillejos',
#  '0307105': 'Iba',
#  '0307106': 'Masinloc',
#  '0307108': 'Palauig',
#  '0307109': 'San Antonio',
#  '0307110': 'San Felipe',
#  '0307111': 'San Marcelino',
#  '0307112': 'San Narciso',
#  '0307113': 'Santa Cruz',
#  '0307114': 'Subic',
#  '0307701': 'Baler',
#  '0307702': 'Casiguran',
#  '0307703': 'Dilasag',
#  '0307704': 'Dinalungan',
#  '0307705': 'Dingalan',
#  '0307706': 'Dipaculao',
#  '0307707': 'Maria Aurora',
#  '0307708': 'San Luis',
#  '0401001': 'Agoncillo',
#  '0401002': 'Alitagtag',
#  '0401003': 'Balayan',
#  '0401004': 'Balete',
#  '0401005': 'Batangas City',
#  '0401006': 'Bauan',
#  '0401007': 'City of Calaca',
#  '0401008': 'Calatagan',
#  '0401009': 'Cuenca',
#  '0401010': 'Ibaan',
#  '0401011': 'Laurel',
#  '0401012': 'Lemery',
#  '0401013': 'Lian',
#  '0401014': 'City of Lipa',
#  '0401015': 'Lobo',
#  '0401016': 'Mabini',
#  '0401017': 'Malvar',
#  '0401018': 'Mataasnakahoy',
#  '0401019': 'Nasugbu',
#  '0401020': 'Padre Garcia',
#  '0401021': 'Rosario',
#  '0401022': 'San Jose',
#  '0401023': 'San Juan',
#  '0401024': 'San Luis',
#  '0401025': 'San Nicolas',
#  '0401026': 'San Pascual',
#  '0401027': 'Santa Teresita',
#  '0401028': 'City of Sto. Tomas',
#  '0401029': 'Taal',
#  '0401030': 'Talisay',
#  '0401031': 'City of Tanauan',
#  '0401032': 'Taysan',
#  '0401033': 'Tingloy',
#  '0401034': 'Tuy',
#  '0402101': 'Alfonso',
#  '0402102': 'Amadeo',
#  '0402103': 'City of Bacoor',
#  '0402104': 'City of Carmona',
#  '0402105': 'City of Cavite',
#  '0402106': 'City of Dasmariñas',
#  '0402107': 'General Emilio Aguinaldo',
#  '0402108': 'City of General Trias',
#  '0402109': 'City of Imus',
#  '0402110': 'Indang',
#  '0402111': 'Kawit',
#  '0402112': 'Magallanes',
#  '0402113': 'Maragondon',
#  '0402114': 'Mendez',
#  '0402115': 'Naic',
#  '0402116': 'Noveleta',
#  '0402117': 'Rosario',
#  '0402118': 'Silang',
#  '0402119': 'City of Tagaytay',
#  '0402120': 'Tanza',
#  '0402121': 'Ternate',
#  '0402122': 'City of Trece Martires',
#  '0402123': 'Gen. Mariano Alvarez',
#  '0403401': 'Alaminos',
#  '0403402': 'Bay',
#  '0403403': 'City of Biñan',
#  '0403404': 'City of Cabuyao',
#  '0403405': 'City of Calamba',
#  '0403406': 'Calauan',
#  '0403407': 'Cavinti',
#  '0403408': 'Famy',
#  '0403409': 'Kalayaan',
#  '0403410': 'Liliw',
#  '0403411': 'Los Baños',
#  '0403412': 'Luisiana',
#  '0403413': 'Lumban',
#  '0403414': 'Mabitac',
#  '0403415': 'Magdalena',
#  '0403416': 'Majayjay',
#  '0403417': 'Nagcarlan',
#  '0403418': 'Paete',
#  '0403419': 'Pagsanjan',
#  '0403420': 'Pakil',
#  '0403421': 'Pangil',
#  '0403422': 'Pila',
#  '0403423': 'Rizal',
#  '0403424': 'City of San Pablo',
#  '0403425': 'City of San Pedro',
#  '0403426': 'Santa Cruz',
#  '0403427': 'Santa Maria',
#  '0403428': 'City of Santa Rosa',
#  '0403429': 'Siniloan',
#  '0403430': 'Victoria',
#  '0405601': 'Agdangan',
#  '0405602': 'Alabat',
#  '0405603': 'Atimonan',
#  '0405605': 'Buenavista',
#  '0405606': 'Burdeos',
#  '0405607': 'Calauag',
#  '0405608': 'Candelaria',
#  '0405610': 'Catanauan',
#  '0405615': 'Dolores',
#  '0405616': 'General Luna',
#  '0405617': 'General Nakar',
#  '0405618': 'Guinayangan',
#  '0405619': 'Gumaca',
#  '0405620': 'Infanta',
#  '0405621': 'Jomalig',
#  '0405622': 'Lopez',
#  '0405623': 'Lucban',
#  '0405625': 'Macalelon',
#  '0405627': 'Mauban',
#  '0405628': 'Mulanay',
#  '0405629': 'Padre Burgos',
#  '0405630': 'Pagbilao',
#  '0405631': 'Panukulan',
#  '0405632': 'Patnanungan',
#  '0405633': 'Perez',
#  '0405634': 'Pitogo',
#  '0405635': 'Plaridel',
#  '0405636': 'Polillo',
#  '0405637': 'Quezon',
#  '0405638': 'Real',
#  '0405639': 'Sampaloc',
#  '0405640': 'San Andres',
#  '0405641': 'San Antonio',
#  '0405642': 'San Francisco',
#  '0405644': 'San Narciso',
#  '0405645': 'Sariaya',
#  '0405646': 'Tagkawayan',
#  '0405647': 'City of Tayabas',
#  '0405648': 'Tiaong',
#  '0405649': 'Unisan',
#  '0405801': 'Angono',
#  '0405802': 'City of Antipolo',
#  '0405803': 'Baras',
#  '0405804': 'Binangonan',
#  '0405805': 'Cainta',
#  '0405806': 'Cardona',
#  '0405807': 'Jala-Jala',
#  '0405808': 'Rodriguez',
#  '0405809': 'Morong',
#  '0405810': 'Pililla',
#  '0405811': 'San Mateo',
#  '0405812': 'Tanay',
#  '0405813': 'Taytay',
#  '0405814': 'Teresa',
#  '0500501': 'Bacacay',
#  '0500502': 'Camalig',
#  '0500503': 'Daraga',
#  '0500504': 'Guinobatan',
#  '0500505': 'Jovellar',
#  '0500506': 'City of Legazpi',
#  '0500507': 'Libon',
#  '0500508': 'City of Ligao',
#  '0500509': 'Malilipot',
#  '0500510': 'Malinao',
#  '0500511': 'Manito',
#  '0500512': 'Oas',
#  '0500513': 'Pio Duran',
#  '0500514': 'Polangui',
#  '0500515': 'Rapu-Rapu',
#  '0500516': 'Santo Domingo',
#  '0500517': 'City of Tabaco',
#  '0500518': 'Tiwi',
#  '0501601': 'Basud',
#  '0501602': 'Capalonga',
#  '0501603': 'Daet',
#  '0501604': 'San Lorenzo Ruiz',
#  '0501605': 'Jose Panganiban',
#  '0501606': 'Labo',
#  '0501607': 'Mercedes',
#  '0501608': 'Paracale',
#  '0501609': 'San Vicente',
#  '0501610': 'Santa Elena',
#  '0501611': 'Talisay',
#  '0501612': 'Vinzons',
#  '0501701': 'Baao',
#  '0501702': 'Balatan',
#  '0501703': 'Bato',
#  '0501704': 'Bombon',
#  '0501705': 'Buhi',
#  '0501706': 'Bula',
#  '0501707': 'Cabusao',
#  '0501708': 'Calabanga',
#  '0501709': 'Camaligan',
#  '0501710': 'Canaman',
#  '0501711': 'Caramoan',
#  '0501712': 'Del Gallego',
#  '0501713': 'Gainza',
#  '0501714': 'Garchitorena',
#  '0501715': 'Goa',
#  '0501716': 'City of Iriga',
#  '0501717': 'Lagonoy',
#  '0501718': 'Libmanan',
#  '0501719': 'Lupi',
#  '0501720': 'Magarao',
#  '0501721': 'Milaor',
#  '0501722': 'Minalabac',
#  '0501723': 'Nabua',
#  '0501724': 'City of Naga',
#  '0501725': 'Ocampo',
#  '0501726': 'Pamplona',
#  '0501727': 'Pasacao',
#  '0501728': 'Pili',
#  '0501729': 'Presentacion',
#  '0501730': 'Ragay',
#  '0501731': 'Sagñay',
#  '0501732': 'San Fernando',
#  '0501733': 'San Jose',
#  '0501734': 'Sipocot',
#  '0501735': 'Siruma',
#  '0501736': 'Tigaon',
#  '0501737': 'Tinambac',
#  '0502001': 'Bagamanoc',
#  '0502002': 'Baras',
#  '0502003': 'Bato',
#  '0502004': 'Caramoran',
#  '0502005': 'Gigmoto',
#  '0502006': 'Pandan',
#  '0502007': 'Panganiban',
#  '0502008': 'San Andres',
#  '0502009': 'San Miguel',
#  '0502010': 'Viga',
#  '0502011': 'Virac',
#  '0504101': 'Aroroy',
#  '0504102': 'Baleno',
#  '0504103': 'Balud',
#  '0504104': 'Batuan',
#  '0504105': 'Cataingan',
#  '0504106': 'Cawayan',
#  '0504107': 'Claveria',
#  '0504108': 'Dimasalang',
#  '0504109': 'Esperanza',
#  '0504110': 'Mandaon',
#  '0504111': 'City of Masbate',
#  '0504112': 'Milagros',
#  '0504113': 'Mobo',
#  '0504114': 'Monreal',
#  '0504115': 'Palanas',
#  '0504116': 'Pio V. Corpus',
#  '0504117': 'Placer',
#  '0504118': 'San Fernando',
#  '0504119': 'San Jacinto',
#  '0504120': 'San Pascual',
#  '0504121': 'Uson',
#  '0506202': 'Barcelona',
#  '0506203': 'Bulan',
#  '0506204': 'Bulusan',
#  '0506205': 'Casiguran',
#  '0506206': 'Castilla',
#  '0506207': 'Donsol',
#  '0506208': 'Gubat',
#  '0506209': 'Irosin',
#  '0506210': 'Juban',
#  '0506211': 'Magallanes',
#  '0506212': 'Matnog',
#  '0506213': 'Pilar',
#  '0506214': 'Prieto Diaz',
#  '0506215': 'Santa Magdalena',
#  '0506216': 'City of Sorsogon',
#  '0600401': 'Altavas',
#  '0600402': 'Balete',
#  '0600403': 'Banga',
#  '0600404': 'Batan',
#  '0600405': 'Buruanga',
#  '0600406': 'Ibajay',
#  '0600407': 'Kalibo',
#  '0600408': 'Lezo',
#  '0600409': 'Libacao',
#  '0600410': 'Madalag',
#  '0600411': 'Makato',
#  '0600412': 'Malay',
#  '0600413': 'Malinao',
#  '0600414': 'Nabas',
#  '0600415': 'New Washington',
#  '0600416': 'Numancia',
#  '0600417': 'Tangalan',
#  '0600601': 'Anini-Y',
#  '0600602': 'Barbaza',
#  '0600603': 'Belison',
#  '0600604': 'Bugasong',
#  '0600605': 'Caluya',
#  '0600606': 'Culasi',
#  '0600607': 'Tobias Fornier',
#  '0600608': 'Hamtic',
#  '0600609': 'Laua-An',
#  '0600610': 'Libertad',
#  '0600611': 'Pandan',
#  '0600612': 'Patnongon',
#  '0600613': 'San Jose',
#  '0600614': 'San Remigio',
#  '0600615': 'Sebaste',
#  '0600616': 'Sibalom',
#  '0600617': 'Tibiao',
#  '0600618': 'Valderrama',
#  '0601901': 'Cuartero',
#  '0601902': 'Dao',
#  '0601903': 'Dumalag',
#  '0601904': 'Dumarao',
#  '0601905': 'Ivisan',
#  '0601906': 'Jamindan',
#  '0601907': 'Ma-Ayon',
#  '0601908': 'Mambusao',
#  '0601909': 'Panay',
#  '0601910': 'Panitan',
#  '0601911': 'Pilar',
#  '0601912': 'Pontevedra',
#  '0601913': 'President Roxas',
#  '0601914': 'City of Roxas',
#  '0601915': 'Sapi-An',
#  '0601916': 'Sigma',
#  '0601917': 'Tapaz',
#  '0603001': 'Ajuy',
#  '0603002': 'Alimodian',
#  '0603003': 'Anilao',
#  '0603004': 'Badiangan',
#  '0603005': 'Balasan',
#  '0603006': 'Banate',
#  '0603007': 'Barotac Nuevo',
#  '0603008': 'Barotac Viejo',
#  '0603009': 'Batad',
#  '0603010': 'Bingawan',
#  '0603012': 'Cabatuan',
#  '0603013': 'Calinog',
#  '0603014': 'Carles',
#  '0603015': 'Concepcion',
#  '0603016': 'Dingle',
#  '0603017': 'Dueñas',
#  '0603018': 'Dumangas',
#  '0603019': 'Estancia',
#  '0603020': 'Guimbal',
#  '0603021': 'Igbaras',
#  '0603023': 'Janiuay',
#  '0603025': 'Lambunao',
#  '0603026': 'Leganes',
#  '0603027': 'Lemery',
#  '0603028': 'Leon',
#  '0603029': 'Maasin',
#  '0603030': 'Miagao',
#  '0603031': 'Mina',
#  '0603032': 'New Lucena',
#  '0603034': 'Oton',
#  '0603035': 'City of Passi',
#  '0603036': 'Pavia',
#  '0603037': 'Pototan',
#  '0603038': 'San Dionisio',
#  '0603039': 'San Enrique',
#  '0603040': 'San Joaquin',
#  '0603041': 'San Miguel',
#  '0603042': 'San Rafael',
#  '0603043': 'Santa Barbara',
#  '0603044': 'Sara',
#  '0603045': 'Tigbauan',
#  '0603046': 'Tubungan',
#  '0603047': 'Zarraga',
#  '0607901': 'Buenavista',
#  '0607902': 'Jordan',
#  '0607903': 'Nueva Valencia',
#  '0607904': 'San Lorenzo',
#  '0607905': 'Sibunag',
#  '0701201': 'Alburquerque',
#  '0701202': 'Alicia',
#  '0701203': 'Anda',
#  '0701204': 'Antequera',
#  '0701205': 'Baclayon',
#  '0701206': 'Balilihan',
#  '0701207': 'Batuan',
#  '0701208': 'Bilar',
#  '0701209': 'Buenavista',
#  '0701210': 'Calape',
#  '0701211': 'Candijay',
#  '0701212': 'Carmen',
#  '0701213': 'Catigbian',
#  '0701214': 'Clarin',
#  '0701215': 'Corella',
#  '0701216': 'Cortes',
#  '0701217': 'Dagohoy',
#  '0701218': 'Danao',
#  '0701219': 'Dauis',
#  '0701220': 'Dimiao',
#  '0701221': 'Duero',
#  '0701222': 'Garcia Hernandez',
#  '0701223': 'Guindulman',
#  '0701224': 'Inabanga',
#  '0701225': 'Jagna',
#  '0701226': 'Getafe',
#  '0701227': 'Lila',
#  '0701228': 'Loay',
#  '0701229': 'Loboc',
#  '0701230': 'Loon',
#  '0701231': 'Mabini',
#  '0701232': 'Maribojoc',
#  '0701233': 'Panglao',
#  '0701234': 'Pilar',
#  '0701235': 'President Carlos P. Garcia',
#  '0701236': 'Sagbayan',
#  '0701237': 'San Isidro',
#  '0701238': 'San Miguel',
#  '0701239': 'Sevilla',
#  '0701240': 'Sierra Bullones',
#  '0701241': 'Sikatuna',
#  '0701242': 'City of Tagbilaran',
#  '0701243': 'Talibon',
#  '0701244': 'Trinidad',
#  '0701245': 'Tubigon',
#  '0701246': 'Ubay',
#  '0701247': 'Valencia',
#  '0701248': 'Bien Unido',
#  '0702201': 'Alcantara',
#  '0702202': 'Alcoy',
#  '0702203': 'Alegria',
#  '0702204': 'Aloguinsan',
#  '0702205': 'Argao',
#  '0702206': 'Asturias',
#  '0702207': 'Badian',
#  '0702208': 'Balamban',
#  '0702209': 'Bantayan',
#  '0702210': 'Barili',
#  '0702211': 'City of Bogo',
#  '0702212': 'Boljoon',
#  '0702213': 'Borbon',
#  '0702214': 'City of Carcar',
#  '0702215': 'Carmen',
#  '0702216': 'Catmon',
#  '0702218': 'Compostela',
#  '0702219': 'Consolacion',
#  '0702220': 'Cordova',
#  '0702221': 'Daanbantayan',
#  '0702222': 'Dalaguete',
#  '0702223': 'Danao City',
#  '0702224': 'Dumanjug',
#  '0702225': 'Ginatilan',
#  '0702227': 'Liloan',
#  '0702228': 'Madridejos',
#  '0702229': 'Malabuyoc',
#  '0702231': 'Medellin',
#  '0702232': 'Minglanilla',
#  '0702233': 'Moalboal',
#  '0702234': 'City of Naga',
#  '0702235': 'Oslob',
#  '0702236': 'Pilar',
#  '0702237': 'Pinamungajan',
#  '0702238': 'Poro',
#  '0702239': 'Ronda',
#  '0702240': 'Samboan',
#  '0702241': 'San Fernando',
#  '0702242': 'San Francisco',
#  '0702243': 'San Remigio',
#  '0702244': 'Santa Fe',
#  '0702245': 'Santander',
#  '0702246': 'Sibonga',
#  '0702247': 'Sogod',
#  '0702248': 'Tabogon',
#  '0702249': 'Tabuelan',
#  '0702250': 'City of Talisay',
#  '0702251': 'City of Toledo',
#  '0702252': 'Tuburan',
#  '0702253': 'Tudela',
#  '0802601': 'Arteche',
#  '0802602': 'Balangiga',
#  '0802603': 'Balangkayan',
#  '0802604': 'City of Borongan',
#  '0802605': 'Can-Avid',
#  '0802606': 'Dolores',
#  '0802607': 'General Macarthur',
#  '0802608': 'Giporlos',
#  '0802609': 'Guiuan',
#  '0802610': 'Hernani',
#  '0802611': 'Jipapad',
#  '0802612': 'Lawaan',
#  '0802613': 'Llorente',
#  '0802614': 'Maslog',
#  '0802615': 'Maydolong',
#  '0802616': 'Mercedes',
#  '0802617': 'Oras',
#  '0802618': 'Quinapondan',
#  '0802619': 'Salcedo',
#  '0802620': 'San Julian',
#  '0802621': 'San Policarpo',
#  '0802622': 'Sulat',
#  '0802623': 'Taft',
#  '0803701': 'Abuyog',
#  '0803702': 'Alangalang',
#  '0803703': 'Albuera',
#  '0803705': 'Babatngon',
#  '0803706': 'Barugo',
#  '0803707': 'Bato',
#  '0803708': 'City of Baybay',
#  '0803710': 'Burauen',
#  '0803713': 'Calubian',
#  '0803714': 'Capoocan',
#  '0803715': 'Carigara',
#  '0803717': 'Dagami',
#  '0803718': 'Dulag',
#  '0803719': 'Hilongos',
#  '0803720': 'Hindang',
#  '0803721': 'Inopacan',
#  '0803722': 'Isabel',
#  '0803723': 'Jaro',
#  '0803724': 'Javier',
#  '0803725': 'Julita',
#  '0803726': 'Kananga',
#  '0803728': 'La Paz',
#  '0803729': 'Leyte',
#  '0803730': 'Macarthur',
#  '0803731': 'Mahaplag',
#  '0803733': 'Matag-Ob',
#  '0803734': 'Matalom',
#  '0803735': 'Mayorga',
#  '0803736': 'Merida',
#  '0803738': 'Ormoc City',
#  '0803739': 'Palo',
#  '0803740': 'Palompon',
#  '0803741': 'Pastrana',
#  '0803742': 'San Isidro',
#  '0803743': 'San Miguel',
#  '0803744': 'Santa Fe',
#  '0803745': 'Tabango',
#  '0803746': 'Tabontabon',
#  '0803748': 'Tanauan',
#  '0803749': 'Tolosa',
#  '0803750': 'Tunga',
#  '0803751': 'Villaba',
#  '0804801': 'Allen',
#  '0804802': 'Biri',
#  '0804803': 'Bobon',
#  '0804804': 'Capul',
#  '0804805': 'Catarman',
#  '0804806': 'Catubig',
#  '0804807': 'Gamay',
#  '0804808': 'Laoang',
#  '0804809': 'Lapinig',
#  '0804810': 'Las Navas',
#  '0804811': 'Lavezares',
#  '0804812': 'Mapanas',
#  '0804813': 'Mondragon',
#  '0804814': 'Palapag',
#  '0804815': 'Pambujan',
#  '0804816': 'Rosario',
#  '0804817': 'San Antonio',
#  '0804818': 'San Isidro',
#  '0804819': 'San Jose',
#  '0804820': 'San Roque',
#  '0804821': 'San Vicente',
#  '0804822': 'Silvino Lobos',
#  '0804823': 'Victoria',
#  '0804824': 'Lope De Vega',
#  '0806001': 'Almagro',
#  '0806002': 'Basey',
#  '0806003': 'City of Calbayog',
#  '0806004': 'Calbiga',
#  '0806005': 'City of Catbalogan',
#  '0806006': 'Daram',
#  '0806007': 'Gandara',
#  '0806008': 'Hinabangan',
#  '0806009': 'Jiabong',
#  '0806010': 'Marabut',
#  '0806011': 'Matuguinao',
#  '0806012': 'Motiong',
#  '0806013': 'Pinabacdao',
#  '0806014': 'San Jose De Buan',
#  '0806015': 'San Sebastian',
#  '0806016': 'Santa Margarita',
#  '0806017': 'Santa Rita',
#  '0806018': 'Santo Niño',
#  '0806019': 'Talalora',
#  '0806020': 'Tarangnan',
#  '0806021': 'Villareal',
#  '0806022': 'Paranas',
#  '0806023': 'Zumarraga',
#  '0806024': 'Tagapul-An',
#  '0806025': 'San Jorge',
#  '0806026': 'Pagsanghan',
#  '0806401': 'Anahawan',
#  '0806402': 'Bontoc',
#  '0806403': 'Hinunangan',
#  '0806404': 'Hinundayan',
#  '0806405': 'Libagon',
#  '0806406': 'Liloan',
#  '0806407': 'City of Maasin',
#  '0806408': 'Macrohon',
#  '0806409': 'Malitbog',
#  '0806410': 'Padre Burgos',
#  '0806411': 'Pintuyan',
#  '0806412': 'Saint Bernard',
#  '0806413': 'San Francisco',
#  '0806414': 'San Juan',
#  '0806415': 'San Ricardo',
#  '0806416': 'Silago',
#  '0806417': 'Sogod',
#  '0806418': 'Tomas Oppus',
#  '0806419': 'Limasawa',
#  '0807801': 'Almeria',
#  '0807802': 'Biliran',
#  '0807803': 'Cabucgayan',
#  '0807804': 'Caibiran',
#  '0807805': 'Culaba',
#  '0807806': 'Kawayan',
#  '0807807': 'Maripipi',
#  '0807808': 'Naval',
#  '0906601': 'Indanan',
#  '0906602': 'Jolo',
#  '0906603': 'Kalingalan Caluang',
#  '0906604': 'Luuk',
#  '0906605': 'Maimbung',
#  '0906606': 'Hadji Panglima Tahil',
#  '0906607': 'Old Panamao',
#  '0906608': 'Pangutaran',
#  '0906609': 'Parang',
#  '0906610': 'Pata',
#  '0906611': 'Patikul',
#  '0906612': 'Siasi',
#  '0906613': 'Talipao',
#  '0906614': 'Tapul',
#  '0906615': 'Tongkil',
#  '0906616': 'Panglima Estino',
#  '0906617': 'Lugus',
#  '0906618': 'Pandami',
#  '0906619': 'Omar',
#  '0907201': 'City of Dapitan',
#  '0907202': 'City of Dipolog',
#  '0907203': 'Katipunan',
#  '0907204': 'La Libertad',
#  '0907205': 'Labason',
#  '0907206': 'Liloy',
#  '0907207': 'Manukan',
#  '0907208': 'Mutia',
#  '0907209': 'Piñan',
#  '0907210': 'Polanco',
#  '0907211': 'Pres. Manuel A. Roxas',
#  '0907212': 'Rizal',
#  '0907213': 'Salug',
#  '0907214': 'Sergio Osmeña Sr.',
#  '0907215': 'Siayan',
#  '0907216': 'Sibuco',
#  '0907217': 'Sibutad',
#  '0907218': 'Sindangan',
#  '0907219': 'Siocon',
#  '0907220': 'Sirawai',
#  '0907221': 'Tampilisan',
#  '0907222': 'Jose Dalman',
#  '0907223': 'Gutalac',
#  '0907224': 'Baliguian',
#  '0907225': 'Godod',
#  '0907226': 'Leon T. Postigo',
#  '0907227': 'Kalawit',
#  '0907302': 'Aurora',
#  '0907303': 'Bayog',
#  '0907305': 'Dimataling',
#  '0907306': 'Dinas',
#  '0907307': 'Dumalinao',
#  '0907308': 'Dumingag',
#  '0907311': 'Kumalarang',
#  '0907312': 'Labangan',
#  '0907313': 'Lapuyan',
#  '0907315': 'Mahayag',
#  '0907317': 'Margosatubig',
#  '0907318': 'Midsalip',
#  '0907319': 'Molave',
#  ...}

# %%
df["region"] = df["region_mapper"].map(regions_mapper)
df["province_or_huc"] = df["province_or_huc_mapper"].map(province_or_huc_mapper)
df["municipality_or_city"] = df["municipal_or_city_mapper"].map(municipal_or_city_mapper)

# %%
barangay_df = df[df["geographic_level"]=="barangay"].reset_index(drop=True)

# %%
# building dictionary
empty_municipality = barangay_df["municipality_or_city"].isna()
empty_province_or_huc = barangay_df["province_or_huc"].isna()

# %%
mdf = barangay_df[~empty_municipality & ~empty_province_or_huc][
    [
        "region",
        "region_mapper",
        "province_or_huc",
        "province_or_huc_mapper",
        "municipality_or_city",
        "municipal_or_city_mapper",
        "name"
    ]
].sort_values(["region", "province_or_huc", "municipality_or_city"])

empty_municipality_df = barangay_df[empty_municipality & ~empty_province_or_huc][
    [
        "region",
        "region_mapper",
        "province_or_huc",
        "province_or_huc_mapper",
        "municipality_or_city",
        "municipal_or_city_mapper",
        "name"
    ]
].sort_values(["region", "province_or_huc", "municipality_or_city"])

empty_province_df = barangay_df[~empty_municipality & empty_province_or_huc][
    [
        "region",
        "region_mapper",
        "province_or_huc",
        "province_or_huc_mapper",
        "municipality_or_city",
        "municipal_or_city_mapper",
        "name"
    ]
].sort_values(["region", "province_or_huc", "municipality_or_city"])

# %%
root_dict: Dict[str, Dict[str, Set[str] | Dict[str, Set]]] = {}
for idx,(i, j, k, l) in mdf[["region","province_or_huc", "municipality_or_city","name"]].iterrows():
    if i not in root_dict.keys():
        root_dict[i] = {}
    if j not in root_dict[i].keys():
        root_dict[i][j] = {}
    if k not in root_dict[i][j].keys():
        root_dict[i][j][k] = set()
    root_dict[i][j][k].add(l)

# handling empty municipality
for idx,(i,j,k) in empty_municipality_df[["region","province_or_huc","name"]].iterrows():
    if i not in root_dict.keys():
        root_dict[i] = {}
    if j not in root_dict[i].keys():
        root_dict[i][j] = set()
    root_dict[i][j].add(k)

# handling empty prov
for idx,(i,j,k) in empty_province_df[["region","municipality_or_city","name"]].iterrows():
    if i not in root_dict.keys():
        root_dict[i] = {}
    if j not in root_dict[i].keys():
        root_dict[i][j] = set()
    root_dict[i][j].add(k)

# %%
json_str = json.dumps(root_dict, default=lambda o: list(o) if isinstance(o, set) else o, indent=4)
json_dict = json.loads(json_str)
yaml_str = yaml.safe_dump(json_dict)

# %%
with open("../barangay/data/barangay.json", encoding="utf8", mode="w") as file:
    file.write(json_str)

# %%
with open("../barangay/data/barangay.yaml", encoding="utf8", mode="w") as file:
    file.write(yaml_str)
